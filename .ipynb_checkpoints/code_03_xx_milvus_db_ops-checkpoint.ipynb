# %%
# !pip install pymilvus==2.3.5
#!pip install openai==1.6.1
# !pip install openai==0.28.1
# !pip install langchain==0.0.354
# !pip install tiktoken==0.5.2
# !pip install transformers==4.36.2
# !pip install pandas==2.1.4
# !pip install pdfminer==20191125
# !pip install pdfminer.six==20221105
# Out:
# Requirement already satisfied: pymilvus==2.3.5 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (2.3.5)
# Requirement already satisfied: grpcio<=1.58.0,>=1.49.1 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from pymilvus==2.3.5) (1.58.0)
# Requirement already satisfied: protobuf>=3.20.0 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from pymilvus==2.3.5) (6.33.5)
# Requirement already satisfied: environs<=9.5.0 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from pymilvus==2.3.5) (9.5.0)
# Requirement already satisfied: ujson>=2.0.0 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from pymilvus==2.3.5) (5.11.0)
# Requirement already satisfied: pandas>=1.2.4 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from pymilvus==2.3.5) (2.1.4)
# Requirement already satisfied: requests in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from pymilvus==2.3.5) (2.32.5)
# Requirement already satisfied: minio>=7.0.0 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from pymilvus==2.3.5) (7.2.20)
# Requirement already satisfied: pyarrow>=12.0.0 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from pymilvus==2.3.5) (23.0.1)
# Requirement already satisfied: marshmallow>=3.0.0 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from environs<=9.5.0->pymilvus==2.3.5) (3.26.2)
# Requirement already satisfied: python-dotenv in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from environs<=9.5.0->pymilvus==2.3.5) (1.2.1)
# Requirement already satisfied: packaging>=17.0 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from marshmallow>=3.0.0->environs<=9.5.0->pymilvus==2.3.5) (23.2)
# Requirement already satisfied: argon2-cffi in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from minio>=7.0.0->pymilvus==2.3.5) (25.1.0)
# Requirement already satisfied: certifi in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from minio>=7.0.0->pymilvus==2.3.5) (2026.1.4)
# Requirement already satisfied: pycryptodome in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from minio>=7.0.0->pymilvus==2.3.5) (3.23.0)
# Requirement already satisfied: typing-extensions in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from minio>=7.0.0->pymilvus==2.3.5) (4.15.0)
# Requirement already satisfied: urllib3 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from minio>=7.0.0->pymilvus==2.3.5) (2.6.3)
# Requirement already satisfied: numpy<2,>=1.23.2 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from pandas>=1.2.4->pymilvus==2.3.5) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from pandas>=1.2.4->pymilvus==2.3.5) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from pandas>=1.2.4->pymilvus==2.3.5) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from pandas>=1.2.4->pymilvus==2.3.5) (2025.3)
# Requirement already satisfied: six>=1.5 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.2.4->pymilvus==2.3.5) (1.17.0)
# Requirement already satisfied: argon2-cffi-bindings in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from argon2-cffi->minio>=7.0.0->pymilvus==2.3.5) (25.1.0)
# Requirement already satisfied: cffi>=1.0.1 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from argon2-cffi-bindings->argon2-cffi->minio>=7.0.0->pymilvus==2.3.5) (2.0.0)
# Requirement already satisfied: pycparser in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->minio>=7.0.0->pymilvus==2.3.5) (2.23)
# Requirement already satisfied: charset_normalizer<4,>=2 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from requests->pymilvus==2.3.5) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from requests->pymilvus==2.3.5) (3.11)
# Requirement already satisfied: openai==0.28.1 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (0.28.1)
# Requirement already satisfied: requests>=2.20 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from openai==0.28.1) (2.32.5)
# Requirement already satisfied: tqdm in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from openai==0.28.1) (4.67.3)
# Requirement already satisfied: aiohttp in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from openai==0.28.1) (3.13.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from requests>=2.20->openai==0.28.1) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from requests>=2.20->openai==0.28.1) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from requests>=2.20->openai==0.28.1) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from requests>=2.20->openai==0.28.1) (2026.1.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from aiohttp->openai==0.28.1) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from aiohttp->openai==0.28.1) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from aiohttp->openai==0.28.1) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from aiohttp->openai==0.28.1) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from aiohttp->openai==0.28.1) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from aiohttp->openai==0.28.1) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from aiohttp->openai==0.28.1) (1.22.0)
# Requirement already satisfied: typing-extensions>=4.2 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from aiosignal>=1.4.0->aiohttp->openai==0.28.1) (4.15.0)
# Requirement already satisfied: colorama in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from tqdm->openai==0.28.1) (0.4.6)
# Requirement already satisfied: langchain==0.0.354 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (0.0.354)
# Requirement already satisfied: PyYAML>=5.3 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from langchain==0.0.354) (6.0.3)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from langchain==0.0.354) (2.0.46)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from langchain==0.0.354) (3.13.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from langchain==0.0.354) (0.6.7)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from langchain==0.0.354) (1.33)
# Requirement already satisfied: langchain-community<0.1,>=0.0.8 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from langchain==0.0.354) (0.0.20)
# Requirement already satisfied: langchain-core<0.2,>=0.1.5 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from langchain==0.0.354) (0.1.23)
# Requirement already satisfied: langsmith<0.1.0,>=0.0.77 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from langchain==0.0.354) (0.0.87)
# Requirement already satisfied: numpy<2,>=1 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from langchain==0.0.354) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from langchain==0.0.354) (2.12.5)
# Requirement already satisfied: requests<3,>=2 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from langchain==0.0.354) (2.32.5)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from langchain==0.0.354) (8.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.354) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.354) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.354) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.354) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.354) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.354) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.354) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain==0.0.354) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain==0.0.354) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from jsonpatch<2.0,>=1.33->langchain==0.0.354) (3.0.0)
# Requirement already satisfied: anyio<5,>=3 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from langchain-core<0.2,>=0.1.5->langchain==0.0.354) (4.10.0)
# Requirement already satisfied: packaging<24.0,>=23.2 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from langchain-core<0.2,>=0.1.5->langchain==0.0.354) (23.2)
# Requirement already satisfied: idna>=2.8 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from anyio<5,>=3->langchain-core<0.2,>=0.1.5->langchain==0.0.354) (3.11)
# Requirement already satisfied: sniffio>=1.1 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from anyio<5,>=3->langchain-core<0.2,>=0.1.5->langchain==0.0.354) (1.3.1)
# Requirement already satisfied: typing_extensions>=4.5 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from anyio<5,>=3->langchain-core<0.2,>=0.1.5->langchain==0.0.354) (4.15.0)
# Requirement already satisfied: annotated-types>=0.6.0 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from pydantic<3,>=1->langchain==0.0.354) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from pydantic<3,>=1->langchain==0.0.354) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from pydantic<3,>=1->langchain==0.0.354) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from requests<3,>=2->langchain==0.0.354) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from requests<3,>=2->langchain==0.0.354) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from requests<3,>=2->langchain==0.0.354) (2026.1.4)
# Requirement already satisfied: greenlet>=1 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from SQLAlchemy<3,>=1.4->langchain==0.0.354) (3.3.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain==0.0.354) (1.1.0)
# Requirement already satisfied: tiktoken==0.5.2 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (0.5.2)
# Requirement already satisfied: regex>=2022.1.18 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from tiktoken==0.5.2) (2026.1.15)
# Requirement already satisfied: requests>=2.26.0 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from tiktoken==0.5.2) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from requests>=2.26.0->tiktoken==0.5.2) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from requests>=2.26.0->tiktoken==0.5.2) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from requests>=2.26.0->tiktoken==0.5.2) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from requests>=2.26.0->tiktoken==0.5.2) (2026.1.4)
# Requirement already satisfied: transformers==4.36.2 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (4.36.2)
# Requirement already satisfied: filelock in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from transformers==4.36.2) (3.24.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from transformers==4.36.2) (0.36.2)
# Requirement already satisfied: numpy>=1.17 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from transformers==4.36.2) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from transformers==4.36.2) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from transformers==4.36.2) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from transformers==4.36.2) (2026.1.15)
# Requirement already satisfied: requests in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from transformers==4.36.2) (2.32.5)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from transformers==4.36.2) (0.15.2)
# Requirement already satisfied: safetensors>=0.3.1 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from transformers==4.36.2) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from transformers==4.36.2) (4.67.3)
# Requirement already satisfied: fsspec>=2023.5.0 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.36.2) (2026.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.36.2) (4.15.0)
# Requirement already satisfied: colorama in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from tqdm>=4.27->transformers==4.36.2) (0.4.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from requests->transformers==4.36.2) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from requests->transformers==4.36.2) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from requests->transformers==4.36.2) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from requests->transformers==4.36.2) (2026.1.4)
# Requirement already satisfied: pandas==2.1.4 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.23.2 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from pandas==2.1.4) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from pandas==2.1.4) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from pandas==2.1.4) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from pandas==2.1.4) (2025.3)
# Requirement already satisfied: six>=1.5 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from python-dateutil>=2.8.2->pandas==2.1.4) (1.17.0)
# Requirement already satisfied: pdfminer==20191125 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (20191125)
# Requirement already satisfied: pycryptodome in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from pdfminer==20191125) (3.23.0)
# Requirement already satisfied: pdfminer.six==20221105 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (20221105)
# Requirement already satisfied: charset-normalizer>=2.0.0 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from pdfminer.six==20221105) (3.4.4)
# Requirement already satisfied: cryptography>=36.0.0 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from pdfminer.six==20221105) (46.0.5)
# Requirement already satisfied: cffi>=2.0.0 in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from cryptography>=36.0.0->pdfminer.six==20221105) (2.0.0)
# Requirement already satisfied: pycparser in D:\apps\anaconda3\envs\Milvus\Lib\site-packages (from cffi>=2.0.0->cryptography>=36.0.0->pdfminer.six==20221105) (2.23)

# %% [markdown]
# # Connecting to Milvus

# %%
from pymilvus import connections

connections.add_connection(
    learn={
        "host": "localhost",
        "port": "19530",
        "username": "",
        "password": "",
    }
)

connection_id = "learn"
connections.connect(connection_id)
connections.list_connections()
# Out:
# D:\apps\anaconda3\envs\Milvus\Lib\site-packages\pymilvus\client\__init__.py:6: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound, get_distribution
# [('default', None),
#  ('learn', <pymilvus.client.grpc_handler.GrpcHandler at 0x132ecbab710>)]

# %% [markdown]
# # Creating DB and Users

# %%
from pymilvus import db

current_dbs = db.list_database(using=connection_id)
print("Current databases:", current_dbs)

db_name="course_db"

if (db_name not in current_dbs):
    print("Creating Database:", db_name)
    wiki_db = db.create_database(db_name, using=connection_id)

db.using_database(db_name, using=connection_id)
# Out:
# Current databases: ['default', 'course_db']

# %% [markdown]
# # Creating Users

# %%
from pymilvus import Role, utility

current_users = utility.list_usernames(using=connection_id)
print("Current user list:", current_users)
# Out:
# Current user list: ['root']

# %% [markdown]
# # Creating Collections

# %%
from pymilvus import CollectionSchema, FieldSchema, DataType, Collection
import json
#Define fields
course_id = FieldSchema (
    name="course_id",
    dtype=DataType. INT64,
    is_primary =True,
    max_length=32)
title = FieldSchema (
    name="title",
    dtype=DataType. VARCHAR,
    max_length=256)
description = FieldSchema (
    name="description",
    dtype=DataType. VARCHAR,
    max_length=2048)

#Dim should match the embedding size
desc_embedding = FieldSchema (
    name="desc_embedding",
    dtype=DataType.FLOAT_VECTOR,
    dim=1536
)

#Define Schema
wiki_schema=CollectionSchema(
    fields=[course_id, title, description, desc_embedding],
    description="Course List",
    enable_dynamic_field=True
)

col_name="courses_list"

wiki_collection = Collection(
    name=col_name,
    schema=wiki_schema,
    using=connection_id,
    shard_num=2
)

from pymilvus import utility

print("Current collections: ",utility.list_collections(using=connection_id))

#setup existing collection into another object
r_collection = Collection(col_name, using=connection_id)
print("\n", r_collection.schema)
# Out:
# Current collections:  ['courses_list']
#
#  {'auto_id': False, 'description': 'Course List', 'fields': [{'name': 'course_id', 'description': '', 'type': <DataType.INT64: 5>, 'is_primary': True, 'auto_id': False}, {'name': 'title', 'description': '', 'type': <DataType.VARCHAR: 21>, 'params': {'max_length': 256}}, {'name': 'description', 'description': '', 'type': <DataType.VARCHAR: 21>, 'params': {'max_length': 2048}}, {'name': 'desc_embedding', 'description': '', 'type': <DataType.FLOAT_VECTOR: 101>, 'params': {'dim': 1536}}], 'enable_dynamic_field': True}

# %% [markdown]
# # Inserting Data in Milvus

# %%
import pandas as pd
course_descriptions = pd.read_csv("sample.csv")
course_descriptions.head()
# Out:
#    Course ID                                              Title  \
# 0       1001  clean-IT: Towards Sustainable Digital Technolo...
# 1       1002  HPI Academy: Strategic Design Thinking For Eve...
# 2       1003  Algorithmen und Datenstrukturen mit Detektiv Duke
# 3       1004  Digital Future Literacy - Fit für die digitale...
# 4       1005  Design Thinking 4.0 – The Cultural Dimension o...
#
#                                          Description
# 0  Digitalization is a game changer in the pursui...
# 1  This is an online course for everyone who want...
# 2  Du hast bereits den Java-Kurs auf openHPI gema...
# 3  Im Zuge der Digitalisierung müssen sich viele ...
# 4  Design Thinking is an innovation approach, whi...

# %%
from langchain.llms import OpenAI
from langchain.embeddings import OpenAIEmbeddings
import os

openai_api_key = "abc123"
os.environ["OPENAI_API_KEY"] = openai_api_key

embeddings_model = OpenAIEmbeddings()

# %%
#Preparing Data
i_course_id = course_descriptions["Course ID"].tolist()
i_title = course_descriptions["Title"].tolist()
i_description = course_descriptions["Description"].tolist()

i_desc_embeddings = [embeddings_model.embed_query(i) for i in i_description]

insert_data = [i_course_id, i_title, i_description, i_desc_embeddings]

# %%
#Init Collection object
course_collection = Collection(col_name, using=connection_id)
#Insert Data
mr = course_collection.insert(insert_data)

#Flush the data after insert
print("Inserted data. Now flushing")
course_collection.flush(timeout=180)
# Out:
# Inserted data. Now flushing

# %% [markdown]
# # Building Index

# %%
index_params = {
    "metric_type": "L2",
    "index_type": "IVF_FLAT",
    "params": { "nlist": 1024 },
}

course_collection.create_index(
    field_name="desc_embedding",
    index_params=index_params
)
utility.index_building_progress(col_name, using=connection_id)
# Out:
# {'total_rows': 100, 'indexed_rows': 100, 'pending_index_rows': 0}

# %% [markdown]
# # Query

# %%
course_collection.load()
print("Course Collection Loaded")
# Out:
# Course Collection Loaded

# %%
q_result = course_collection.query(
    expr = "course_id == 1001",
    output_fields = ["title", "description"]
)
print(q_result)
print("\n Result object :", type(q_result[0]))
# Out:
# [{'title': 'clean-IT: Towards Sustainable Digital Technologies', 'description': 'Digitalization is a game changer in the pursuit of a sustainable future. The latest digital technologies and applications like cloud, AI, and mobile devices enable us to achieve the Sustainable Development Goals and reduce carbon emissions in many sectors. Yet computer systems themselves have an immense energy requirement for their countless devices, data centers, applications and global networks. To effectively reduce the carbon footprint of digitalization, it is necessary to apply algorithmic efficiency and sustainability by design as guiding principles in digital engineering. The clean-IT Forum is the international platform to exchange ideas, recent research findings and applications to make digital technologies more energy-efficient.', 'course_id': 1001}]
#
#  Result object : <class 'dict'>

# %%
q_result2 = course_collection.query(
    expr = "(title LIKE 'Cyber%') && (course_id > 1001)",
    output_fields = ["title", "description"]
)
print(q_result2)
# Out:
# [{'title': 'Cybersecurity Basics - Exam', 'description': 'If you have completed the three security workshops offered on openHPI this year, you should now have a good knowledge of the basics of cybersecurity. Here we offer you the opportunity to take an exam on the material from all three workshops. If successful, you will receive a record of achievement or a qualified certificate, which is usually only awarded in 6-week courses.\nYou may not register for the exam until you have met the eligibility requirements. The following criteria must be met:\nParticipation in the 3 Workshops Confidential Communication in the Internet, Digital Identities, Cyberthreats by Malware\nProof of a confirmation of participation in each of the three workshops (access of at least 80% of the learning material)\nThe participation in the weekly assignments in the individual courses is not relevant for this exam.', 'course_id': 1020}, {'title': 'Cyberthreats by Malware', 'description': 'In this course we will discuss a huge problem on the Internet: The spread of malware.\nThe number of cyber attacks has increased again in 2020. New forms of malware have evolved, even more disruptive and more damaging.\nWe will cover different types of malware, such as, viruses, worms, and trojans, talk about botnets and ransomware, and mention some countermeasures.', 'course_id': 1022}, {'title': 'Cybersecurity Basics - Prüfung', 'description': 'Wenn Sie die drei Sicherheits-Workshops absolviert haben, die letztes Jahr auf openHPI angeboten wurden, sollten Sie nun bestens über die Basics der Cybersecurity Bescheid wissen. Hier bieten wir Ihnen die Möglichkeit, eine Prüfung über den Stoff aus allen drei Workshops abzulegen. Bei Erfolg erhalten Sie ein Zeugnis oder ein qualifiziertes Zertifikat, welches üblicherweise nur in 6-Wochen-Kursen vergeben wird.\nEine Einschreibung für die Prüfung ist erst möglich, wenn die Voraussetzungen für die Teilnahme erfüllt sind. Folgende Kriterien müssen erfüllt sein:\nTeilnahme an den 3 Sicherheits-Workshops (Datensicherheit im Netz, Digitale Identitäten, Blockchain - Sicherheit auch ohne Trust Center)\nJeweils Erwerb der Teilnahmebestätigung (Zugriff auf mind. 80% der Lernmaterialien)\nDie Teilnahme an den Wochentests in den einzelnen Kursen ist für diese Prüfung irrelevant.', 'course_id': 1099}]

# %% [markdown]
# # Vector Search Query

# %%
search_params = {
    "metric_type": "L2",
    "offset": 0,
    "ignore_growing": False,
    "params": { "nprobe": 10 }
}
# Vector Embed of Input String
search_string = "cyber"
search_embed = embeddings_model.embed_query(search_string)

#Perform Search
s_results = course_collection.search(
    data=[search_embed],
    anns_field="desc_embedding",
    param=search_params,
    limit=10,
    expr=None,
    output_fields=["title"],
    consistency_level="Strong"
)
print("Search result object:", type(s_results[0]), "\n")

for i in s_results[0]:
    print(i.id, str(round(i.distance, 2)), "\t", i.entity.get("title"))
# Out:
# Search result object: <class 'pymilvus.client.abstract.Hits'>
#
# 1063 0.37 	 Internet Security for Beginners
# 1080 0.38 	 Web Technologies
# 1022 0.39 	 Cyberthreats by Malware
# 1079 0.39 	 Sicherheit im Internet
# 1035 0.39 	 Tatort Internet - Angriffsvektoren und Schutzmaßnahmen
# 1020 0.39 	 Cybersecurity Basics - Exam
# 1066 0.4 	 Social Media - What No One has Told You about Privacy
# 1091 0.4 	 Social Media - What No One has Told You about Privacy
# 1001 0.4 	 clean-IT: Towards Sustainable Digital Technologies
# 1024 0.41 	 Confidential Communication in the Internet

# %%
# Search an unrelated query
search_string2 = "best movies of the year"
search_embed2 = embeddings_model.embed_query(search_string2)

#Perform Search
s_results2 = course_collection.search(
    data=[search_embed2],
    anns_field="desc_embedding",
    param=search_params,
    limit=10,
    expr=None,
    output_fields=["title"],
    consistency_level="Strong"
)
print("Search result object:", type(s_results[0]), "\n")

for i in s_results2[0]:
    print(i.id, str(round(i.distance, 2)), "\t", i.entity.get("title"))
# Out:
# Search result object: <class 'pymilvus.client.abstract.Hits'>
#
# 1080 0.58 	 Web Technologies
# 1058 0.58 	 Java Capstone Series Pt. 1
# 1015 0.59 	 Learning @ Scale 2021 & EMOOCs 2021
# 1025 0.59 	 Future of Computing - on the Road to Quantum
# 1068 0.6 	 In-Memory Data Management
# 1032 0.61 	 HPI Academy: Leading Digital Transformation and Innovation - Fall 2020
# 1022 0.61 	 Cyberthreats by Malware
# 1036 0.61 	 Co-Innovation Journey for Startups and Corporates
# 1048 0.62 	 Future of Computing - IBM POWER9 and beyond
# 1001 0.62 	 clean-IT: Towards Sustainable Digital Technologies

# %% [markdown]
# # Deleting Object

# %%
# Deleting SIngle Record
course_collection.delete("course_id in [1002]")
# Out:
# (insert count: 0, delete count: 1, upsert count: 0, timestamp: 464416447501434881, success count: 0, err count: 0)
